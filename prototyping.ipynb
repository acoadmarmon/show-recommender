# %%
# Use GRPC in Python to grab data from db
import grpc
import grpc_protos.animeengineservice_pb2 as animeengineservice_pb2
import grpc_protos.animeengineservice_pb2_grpc as animeengineservice_pb2_grpc
import json
channel = grpc.insecure_channel('127.0.0.1:58181')
stub = animeengineservice_pb2_grpc.AnimeStub(channel)

# %%
stub.GetReviews(animeengineservice_pb2.GetReviewsRequest(limit=20))
# Out:
# results {
#   score: 80
#   uid: 15756
#   mid: 21306
# }
# results {
#   score: 80
#   uid: 15828
#   mid: 338
# }
# results {
#   score: 70
#   uid: 22662
#   mid: 26
# }
# results {
#   score: 45
#   uid: 69930
#   mid: 21417
# }
# results {
#   score: 85
#   uid: 69930
#   mid: 21202
# }
# results {
#   score: 86
#   uid: 4659
#   mid: 7053
# }
# results {
#   score: 97
#   uid: 30444
#   mid: 603
# }
# results {
#   score: 83
#   uid: 32781
#   mid: 14397
# }
# results {
#   score: 35
#   uid: 69930
#   mid: 21330
# }
# results {
#   score: 70
#   uid: 15828
#   mid: 16662
# }
# results {
#   score: 100
#   uid: 14669
#   mid: 323
# }
# results {
#   score: 60
#   uid: 14669
#   mid: 535
# }
# results {
#   score: 80
#   uid: 69930
#   mid: 21472
# }
# results {
#   score: 60
#   uid: 30949
#   mid: 1827
# }
# results {
#   score: 81
#   uid: 39746
#   mid: 1502
# }
# results {
#   score: 94
#   uid: 39746
#   mid: 20770
# }
# results {
#   score: 77
#   uid: 39746
# ...
